# %%
from IPython.display import Image, display

# Path to your image
image_path = "building_blocks.png"

# Display the image
display(Image(filename=image_path))

# %%
# !pip install -U pandas==1.5.3 numpy==1.26.4 pandasai
# Out:
# Requirement already satisfied: pandas==1.5.3 in ./venv/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: numpy==1.26.4 in ./venv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandasai in ./venv/lib/python3.12/site-packages (2.3.0)
# Collecting langchain_community
#   Downloading langchain_community-0.3.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.12/site-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas==1.5.3) (2024.2)
# Requirement already satisfied: astor<0.9.0,>=0.8.1 in ./venv/lib/python3.12/site-packages (from pandasai) (0.8.1)
# Requirement already satisfied: duckdb<2.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from pandasai) (1.1.3)
# Requirement already satisfied: faker<20.0.0,>=19.12.0 in ./venv/lib/python3.12/site-packages (from pandasai) (19.13.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in ./venv/lib/python3.12/site-packages (from pandasai) (3.1.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in ./venv/lib/python3.12/site-packages (from pandasai) (3.9.2)
# Requirement already satisfied: openai<2 in ./venv/lib/python3.12/site-packages (from pandasai) (1.54.4)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in ./venv/lib/python3.12/site-packages (from pandasai) (10.4.0)
# Requirement already satisfied: pydantic<3,>=1 in ./venv/lib/python3.12/site-packages (from pandasai) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from pandasai) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in ./venv/lib/python3.12/site-packages (from pandasai) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in ./venv/lib/python3.12/site-packages (from pandasai) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4 in ./venv/lib/python3.12/site-packages (from pandasai) (2.0.36)
# Requirement already satisfied: sqlglot<26.0.0,>=25.0.3 in ./venv/lib/python3.12/site-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai) (25.30.0)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.12/site-packages (from langchain_community) (6.0.2)
# Collecting sqlalchemy<3,>=1.4 (from pandasai)
#   Using cached SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.11.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.7 (from langchain_community)
#   Using cached langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.17 (from langchain_community)
#   Downloading langchain_core-0.3.18-py3-none-any.whl.metadata (6.3 kB)
# Collecting langsmith<0.2.0,>=0.1.125 (from langchain_community)
#   Downloading langsmith-0.1.143-py3-none-any.whl.metadata (13 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Using cached pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain_community)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (64 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (3.0.2)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain<0.4.0,>=0.3.7->langchain_community)
#   Using cached langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.17->langchain_community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.125->langchain_community)
#   Using cached orjson-3.10.11-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.125->langchain_community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.12/site-packages (from openai<2->pandasai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai<2->pandasai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai<2->pandasai) (0.7.1)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from openai<2->pandasai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.12/site-packages (from openai<2->pandasai) (4.67.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1->pandasai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1->pandasai) (2.23.4)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2024.8.30)
# Requirement already satisfied: sqlglotrs==0.2.13 in ./venv/lib/python3.12/site-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai) (0.2.13)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.17->langchain_community) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.3.7-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.6 MB/s eta 0:00:00
# Downloading aiohttp-3.11.2-cp312-cp312-macosx_11_0_arm64.whl (454 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.3 MB/s eta 0:00:00
# Downloading langchain_core-0.3.18-py3-none-any.whl (409 kB)
# Downloading langsmith-0.1.143-py3-none-any.whl (306 kB)
# Using cached pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Using cached SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Using cached marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Using cached multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Using cached orjson-3.10.11-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (266 kB)
# Using cached propcache-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (45 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (92 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, sqlalchemy, propcache, orjson, mypy-extensions, multidict, marshmallow, jsonpatch, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, requests-toolbelt, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.11.2 aiosignal-1.3.1 dataclasses-json-0.6.7 frozenlist-1.5.0 httpx-sse-0.4.0 jsonpatch-1.33 langchain-0.3.7 langchain-core-0.3.18 langchain-text-splitters-0.3.2 langchain_community-0.3.7 langsmith-0.1.143 marshmallow-3.23.1 multidict-6.1.0 mypy-extensions-1.0.0 orjson-3.10.11 propcache-0.2.0 pydantic-settings-2.6.1 requests-toolbelt-1.0.0 sqlalchemy-2.0.35 tenacity-9.0.0 typing-inspect-0.9.0 yarl-1.17.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_csv("data.csv")
data.head(10)
# Out:
#    PassengerId  Survived  Pclass                           Name     Sex   Age  \
# 0         1310         1       1    Name1310, Miss. Surname1310  female   NaN
# 1         1311         0       3     Name1311, Col. Surname1311    male  29.0
# 2         1312         0       3      Name1312, Mr. Surname1312    male  20.0
# 3         1313         0       3      Name1313, Mr. Surname1313    male  27.0
# 4         1314         0       3      Name1314, Mr. Surname1314    male  32.0
# 5         1315         1       3  Name1315, Master. Surname1315  female   0.0
# 6         1316         0       1      Name1316, Mr. Surname1316    male   NaN
# 7         1317         1       2    Name1317, Miss. Surname1317  female  28.0
# 8         1318         0       1      Name1318, Mr. Surname1318    male   NaN
# 9         1319         0       2      Name1319, Mr. Surname1319    male  32.0
#
#    SibSp  Parch            Ticket        Fare Cabin Embarked
# 0      0      0  SOTON/O2 3101272   76.760165   NaN        C
# 1      0      0            223596   10.193097   NaN        S
# 2      0      0             54636   12.029416   C83        C
# 3      0      0          PC 17760   13.429448   NaN        S
# 4      0      0            364512    4.840769   E33        C
# 5      0      0             29750   14.805817   NaN        S
# 6      0      0        C.A. 24579  115.806344   NaN        C
# 7      0      1            113781   27.950048   NaN        S
# 8      0      0            250652   29.467203   NaN        S
# 9      0      0             17464    0.000000   NaN        S

# %%
from pandasai import SmartDataframe, SmartDatalake, Agent
from pandasai.llm.local_llm import LocalLLM

employees_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Emma', 'Liam', 'Olivia', 'William'],
    'Department': ['HR', 'Sales', 'IT', 'Marketing', 'Finance']
}

salaries_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Salary': [5000, 6000, 4500, 7000, 5500]
}

employees_df = pd.DataFrame(employees_data)
salaries_df = pd.DataFrame(salaries_data)

llm = LocalLLM(api_base="http://localhost:11434/v1", model="qwen2.5:latest")
# df = SmartDatalake([employees_df, salaries_df], config={"llm":llm})
df = SmartDataframe(df=data, config={"llm":llm})

# %%
df.chat("what is the counts of male and female?")
# Out:
# Result: {'type': 'plot', 'value': '/Users/pavanmantha/Pavans/Workshops/adv_genai_bootcamp/playgrounds/DataAnalysis_Agents/exports/charts/temp_chart.png'}
# '/Users/pavanmantha/Pavans/Workshops/adv_genai_bootcamp/playgrounds/DataAnalysis_Agents/exports/charts/temp_chart.png'

# %%
agent = Agent(dfs=data, config={"llm":llm})
agent.chat("what are the counts of male and female?")
# Out:
#          Count
# male    648840
# female  351160

# %%
agent.chat("how many total deaths and also classify the deaths by sex")
# Out:
#       Sex  Survived
# 0  female    260970
# 1    male    120711

# %%
agent.chat("how many total deaths and classify the deaths by sex and class of the passengers")
# Out:
# Total Deaths: 618319
#    Pclass     Sex  Deaths
# 0       1  female    2787
# 1       1    male   87881
# 2       2  female    6522
# 3       2    male  100476
# 4       3  female   80881
# 5       3    male  339772

# %%
agent.chat("how many total deaths and classify the deaths by sex and class of the passengers in a single stacked graph")
# Out:
# '/Users/pavanmantha/Pavans/Workshops/adv_genai_bootcamp/playgrounds/DataAnalysis_Agents/exports/charts/temp_chart.png'
