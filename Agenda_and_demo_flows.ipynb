# %% [markdown]
# # Agenda :
#
# **Day 1 :**
#
# Intro
# Setup
# LLM Application building blocks
# Agents process flow
# Demo: Llamaindex , PandasAI
# Guest Lecture
# Demo: Flowise

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Day 2:**
#
# - Demo on Agents with Flowise
# - Demo on Copilots
# - Demo on LLamaindex leveraging Agents
# - Break
# - Demo on deployments
# Guest Lectures
# Production Grade deployments and advancements.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Stages of Agents Flow  :
#
#
# - Access the document store
# - Chuck the data store
# - Leverage Embedding model to embed the data
# - Store into a vector DB
# - Retrieve the data
# - Assign it to agent.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Flowise Demo : Critic based on usecases asked:**
#
# - Input Question requested
# - Finetune through prompt
# - Send to LLM ( GROQ & OLLAMA )
# - Generate multiple usecases
# - Prompt for Critic to validate the usecases
# - Pass it to LLM
# - Generate right usecase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
